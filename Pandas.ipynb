# %% [markdown]
# <a href="https://colab.research.google.com/github/Murali134/PandasPractice01/blob/main/Pandas.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd

# %%
df = pd.DataFrame({
    'a': [1, 2, 3]}, index = [0, 1, 2])

df = pd.DataFrame({
    'a': [50, 60, 70]}, index = [2, 0, 1])

df + df
# Out:
#      a
# 2  100
# 0  120
# 1  140

# %%
# Series is a single, indexed sequenced of data
list = [20, 30, 40, 50, 60]
output = pd.Series(list, index= ['0', '1', '2', '3', '4'])
output.loc['2']
# Out:
# np.int64(40)

# %%
# DataFrame is collection of Series, organize into a table form
df = pd.DataFrame({
    'name': ['Muralidhar', 'Sunaina', 'Jyothi'],
    'age': [30, 29, 28],
    'role': ['AI Engineer', 'UX Designer', 'Operations']
})
df = df.set_index('role')
df
# Out:
#                    name  age
# role
# AI Engineer  Muralidhar   30
# UX Designer     Sunaina   29
# Operations       Jyothi   28

# %%
df.loc['AI Engineer']
# Out:
# name    Muralidhar
# age             30
# Name: AI Engineer, dtype: object

# %%
df1 = pd.DataFrame({
    'a': [1, 2, 3]
    }, index = [0, 1, 2])
df2 = pd.DataFrame({
    'a': [20, 30, 40]
    }, index = [2, 0, 1])
df1+df2
# adding 'a' values using indexes
# Out:
#     a
# 0  31
# 1  42
# 2  23

# %%
df = df.reset_index()
df
# Out:
#    index         role        name  age
# 0      0  AI Engineer  Muralidhar   30
# 1      1  UX Designer     Sunaina   29
# 2      2   Operations      Jyothi   28

# %%
df.to_csv('mydata.csv', index= None)
pd.read_csv('mydata.csv', index_col=0)
# Out:
#               role        name  age
# index
# 0      AI Engineer  Muralidhar   30
# 1      UX Designer     Sunaina   29
# 2       Operations      Jyothi   28

# %%
df.to_json('mydata.json')

# %%
df.to_dict()
# dictonary have a key & values(key: values)
# Out:
# {'index': {0: 0, 1: 1, 2: 2},
#  'role': {0: 'AI Engineer', 1: 'UX Designer', 2: 'Operations'},
#  'name': {0: 'Muralidhar', 1: 'Sunaina', 2: 'Jyothi'},
#  'age': {0: 30, 1: 29, 2: 28}}

# %%
#Data Exploration Functions

# %%
from sklearn.datasets import fetch_california_housing

# %%
df = fetch_california_housing(as_frame=True).frame
df
# Out:
#        MedInc  HouseAge  AveRooms  AveBedrms  Population  AveOccup  Latitude  \
# 0      8.3252      41.0  6.984127   1.023810       322.0  2.555556     37.88
# 1      8.3014      21.0  6.238137   0.971880      2401.0  2.109842     37.86
# 2      7.2574      52.0  8.288136   1.073446       496.0  2.802260     37.85
# 3      5.6431      52.0  5.817352   1.073059       558.0  2.547945     37.85
# 4      3.8462      52.0  6.281853   1.081081       565.0  2.181467     37.85
# ...       ...       ...       ...        ...         ...       ...       ...
# 20635  1.5603      25.0  5.045455   1.133333       845.0  2.560606     39.48
# 20636  2.5568      18.0  6.114035   1.315789       356.0  3.122807     39.49
# 20637  1.7000      17.0  5.205543   1.120092      1007.0  2.325635     39.43
# 20638  1.8672      18.0  5.329513   1.171920       741.0  2.123209     39.43
# 20639  2.3886      16.0  5.254717   1.162264      1387.0  2.616981     39.37
#
#        Longitude  MedHouseVal
# ...

# %%
df.columns
# Out:
# Index(['MedInc', 'HouseAge', 'AveRooms', 'AveBedrms', 'Population', 'AveOccup',
#        'Latitude', 'Longitude', 'MedHouseVal'],
#       dtype='object')

# %%
df
# Out:
#        MedInc  HouseAge  AveRooms  AveBedrms  Population  AveOccup  Latitude  \
# 0      8.3252      41.0  6.984127   1.023810       322.0  2.555556     37.88
# 1      8.3014      21.0  6.238137   0.971880      2401.0  2.109842     37.86
# 2      7.2574      52.0  8.288136   1.073446       496.0  2.802260     37.85
# 3      5.6431      52.0  5.817352   1.073059       558.0  2.547945     37.85
# 4      3.8462      52.0  6.281853   1.081081       565.0  2.181467     37.85
# ...       ...       ...       ...        ...         ...       ...       ...
# 20635  1.5603      25.0  5.045455   1.133333       845.0  2.560606     39.48
# 20636  2.5568      18.0  6.114035   1.315789       356.0  3.122807     39.49
# 20637  1.7000      17.0  5.205543   1.120092      1007.0  2.325635     39.43
# 20638  1.8672      18.0  5.329513   1.171920       741.0  2.123209     39.43
# 20639  2.3886      16.0  5.254717   1.162264      1387.0  2.616981     39.37
#
#        Longitude  MedHouseVal
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 20640 entries, 0 to 20639
# Data columns (total 9 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   MedInc       20640 non-null  float64
#  1   HouseAge     20640 non-null  float64
#  2   AveRooms     20640 non-null  float64
#  3   AveBedrms    20640 non-null  float64
#  4   Population   20640 non-null  float64
#  5   AveOccup     20640 non-null  float64
#  6   Latitude     20640 non-null  float64
#  7   Longitude    20640 non-null  float64
#  8   MedHouseVal  20640 non-null  float64
# dtypes: float64(9)
# memory usage: 1.4 MB

# %%
df.describe()
# Out:
#              MedInc      HouseAge      AveRooms     AveBedrms    Population  \
# count  20640.000000  20640.000000  20640.000000  20640.000000  20640.000000
# mean       3.870671     28.639486      5.429000      1.096675   1425.476744
# std        1.899822     12.585558      2.474173      0.473911   1132.462122
# min        0.499900      1.000000      0.846154      0.333333      3.000000
# 25%        2.563400     18.000000      4.440716      1.006079    787.000000
# 50%        3.534800     29.000000      5.229129      1.048780   1166.000000
# 75%        4.743250     37.000000      6.052381      1.099526   1725.000000
# max       15.000100     52.000000    141.909091     34.066667  35682.000000
#
#            AveOccup      Latitude     Longitude   MedHouseVal
# count  20640.000000  20640.000000  20640.000000  20640.000000
# mean       3.070655     35.631861   -119.569704      2.068558
# std       10.386050      2.135952      2.003532      1.153956
# ...

# %%
import matplotlib.pyplot as plt
df['HouseAge'].plot.bar(figsize=(12, 8))
plt.title('House Age')
plt.show()

# %%
import matplotlib.pyplot as plt
df.hist(figsize = (12, 8))
plt.tight_layout()

# %%
import yfinance as yf
stock_df = yf.download('AAPL')
# Out:
# /tmp/ipython-input-2185735600.py:2: FutureWarning: YF.download() has changed argument auto_adjust default to True
#   stock_df = yf.download('AAPL')
# [*********************100%***********************]  1 of 1 completed

# %%
stock_df.plot()
# Out:
# <Axes: xlabel='Date'>

# %%
stock_df.hist()
# Out:
# array([[<Axes: title={'center': "('Close', 'AAPL')"}>,
#         <Axes: title={'center': "('High', 'AAPL')"}>],
#        [<Axes: title={'center': "('Low', 'AAPL')"}>,
#         <Axes: title={'center': "('Open', 'AAPL')"}>],
#        [<Axes: title={'center': "('Volume', 'AAPL')"}>, <Axes: >]],
#       dtype=object)

# %%
import pandas as pd
df = pd.DataFrame({
    'name': ['Muralidhar', 'Sunaina', 'Jyothi'],
    'age': [30, 29, 28],
    'role': ['AI Engineer', 'UX Designer', 'Operations']
})
df
# Out:
#          name  age         role
# 0  Muralidhar   30  AI Engineer
# 1     Sunaina   29  UX Designer
# 2      Jyothi   28   Operations

# %%
df = df.set_index('name')
df.loc['Sunaina']
# Out:
# age              29
# role    UX Designer
# Name: Sunaina, dtype: object

# %%
df.iloc[1, 0]
# Out:
# np.int64(29)

# %%
df.loc['Sunaina', 'age']
# Out:
# np.int64(29)
